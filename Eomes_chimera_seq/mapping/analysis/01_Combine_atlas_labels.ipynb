# %% [markdown]
# # Keeping relevant labels from extended atlas

# %% [markdown]
# Since the extended atlas has 82 labels, we don't want to use all of them (most won't be relevant for our analysis). <br>
# However, some are relevant.<br>
# Here, we mainly keep the original annotations, but additionally use some of the extended atlas labels for relevant cell-types.

# %%
suppressPackageStartupMessages({
    library(dplyr)
    library(data.table)
    library(ggplot2)
})

here::i_am("mapping/analysis/01_Combine_atlas_labels.ipynb")

# Load default settings
source(here::here("settings.R"))
source(here::here("utils.R"))

set.seed(1234)
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/01_Eomes_RNA/code

# %%
meta = fread(paste0(io$basedir,"/results/rna/mapping/manual/sample_metadata_after_mapping.txt.gz"))

# %%
compare = data.table(cell = meta$cell, original = meta$celltype.mapped_mnn, extended = meta$celltype_extended.mapped_mnn) %>%
    .[,count := .N, by=c('original', 'extended')] %>%
    .[,tot := .N, by='original'] %>% .[,prop := count/tot] %>%
    unique(by=c('original', 'extended'))

# %%
options(repr.plot.width=20, repr.plot.height=20)
ggplot(compare[!is.na(original)], aes(original, extended, fill=prop)) + 
    geom_tile() + 
    viridis::scale_fill_viridis(begin=1, end=0) + 
    theme_bw() + 
    theme(axis.text.x = element_text(angle=-90, hjust=0, vjust=0.5),
          axis.text = element_text(color='black', size=15))
# Out:
# plot without title

# %%
original_keep = c('Allantois', 
                  paste0('Blood_progenitors_', 1:2),
                  'Cardiomyocytes',
                  'Caudal_epiblast',
                  'Caudal_Mesoderm',
                  'Caudal_neurectoderm',
                  'Def._endoderm',
                  'Epiblast',
                  'ExE_ectoderm',
                  'ExE_endoderm',
                  'Forebrain_Midbrain_Hindbrain',
                  'Gut',
                  'Nascent_mesoderm',
                  'Neural_crest',
                  'NMP',
                  'Notochord', 
                  'Parietal_endoderm',
                  'PGC',
                  'Pharyngeal_mesoderm',
                  'Rostral_neurectoderm', 
                  'Spinal_cord',
                  'Surface_ectoderm', # Except for amniotic ectoderm
                  'Visceral_endoderm'                  
                )
original_replace = c('Endothelium',
                    paste0('Erythroid', 1:3), # --> Erythroid
                    'ExE_mesoderm', # --> Replace with LPM all together
                     'Haematoendothelial_progenitors',# --> Use exteended atlas label
                   'Mixed_mesoderm' # Use the new labels as they are more precise
                )

# %%
meta = meta[,celltype_updated := celltype.mapped_mnn] %>% 
    # Add higher resolution endothelium annotation
    .[,celltype_updated := ifelse(celltype_updated %in% c('Endothelium', 'Haematoendothelial_progenitors'), celltype_extended.mapped_mnn, celltype_updated), ] %>% 
    # Merge Erythroids 
    .[,celltype_updated := ifelse(celltype_updated %in% paste0('Erythroid', 1:3), 'Erythroid', celltype_updated)] %>%
    # Change 'ExE mesoderm' to 'Lateral plate mesoderm'
    .[,celltype_updated := ifelse(celltype_updated == 'ExE_mesoderm', 'Lateral_plate_mesoderm', celltype_updated)] %>% 
    # Improve mixed mesoderm annotation
    .[,celltype_updated := ifelse(celltype_updated == 'Mixed_mesoderm', celltype_extended.mapped_mnn, celltype_updated)] %>% 
    # Add amniotic ectoderm    
    .[,celltype_updated := ifelse(celltype_extended.mapped_mnn == 'Amniotic_ectoderm', 'Amniotic_ectoderm', celltype_updated)] %>%
    # Add YS mesothelium
    .[,celltype_updated := ifelse(celltype_extended.mapped_mnn == 'YS_mesothelium', 'YS_mesothelium', celltype_updated)]

# %%
compare = data.table(cell = meta$cell, original = meta$celltype.mapped_mnn, celltype_updated = meta$celltype_updated) %>%
    .[,count := .N, by=c('original', 'celltype_updated')] %>%
    .[,tot := .N, by='original'] %>% .[,prop := count/tot] %>%
    unique(by=c('original', 'celltype_updated')) 

options(repr.plot.width=20, repr.plot.height=20)
ggplot(compare[!is.na(original)], aes(original, celltype_updated, fill=prop)) + 
    geom_tile() + 
    viridis::scale_fill_viridis(begin=1, end=0) + 
    theme_bw() + 
    theme(axis.text.x = element_text(angle=-90, hjust=0, vjust=0.5),
          axis.text = element_text(color='black', size=15))
# Out:
# plot without title

# %%
# Load cell metadata
args = list()
args$atlas_metadata = '/rds/project/rds-SDzz0CATGms/users/bt392/atlasses/gastrulation/pijuansala2019_gastrulation10x/sample_metadata_extended.txt.gz'
meta_atlas <- fread(args$atlas_metadata)

# %%
meta = merge(meta, meta_atlas[,c('cell', 'umapX','umapY')], by.x='closest.cell_mnn', by.y='cell')

# %%
options(repr.plot.width=15, repr.plot.height=6)
ggplot(meta, aes(umapX, umapY, color=celltype_updated)) + 
    geom_point(size=0.5) + 
    scale_color_manual(values=c(opts$celltype.colors, opts$celltype_extended.colors)) + 
    facet_wrap(~tdTom) + 
    theme_void() + 
    theme(legend.position='right',
          strip.background=element_blank(),
          strip.text=element_text(size=20))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=6)
ggplot(meta, aes(umapX, umapY, color=celltype.mapped_mnn)) + 
    geom_point(size=0.5) + 
    scale_color_manual(values=c(opts$celltype.colors, opts$celltype_extended.colors)) + 
    facet_wrap(~tdTom) + 
    theme_void() + 
    theme(legend.position='right',
          strip.background=element_blank(),
          strip.text=element_text(size=20))
# Out:
# plot without title

# %%
fwrite(meta, paste0(io$basedir, '/results/rna/mapping/manual/metadata_mapping_updated.txt.gz'))

# %%
meta = fread(paste0(io$basedir, '/results/rna/mapping/manual/metadata_mapping_updated.txt.gz'))

# %%
meta$label = factor(ifelse(meta$tdTom == FALSE, 'WT', 'Eomes-KO'), levels = c('WT', 'Eomes-KO'))

# %%
p = ggplot(meta, aes(umapX, umapY, color=celltype_updated)) + 
    ggrastr::rasterise(geom_point(data = rbind(meta_atlas %>% copy() %>% .[,tdTom:=FALSE], meta_atlas %>% copy() %>% .[,tdTom:=TRUE]), 
               color='black', size = -0.05), dpi = 600) + 
    ggrastr::rasterise(geom_point(data = rbind(meta_atlas %>% copy() %>% .[,tdTom:=FALSE], meta_atlas %>% copy() %>% .[,tdTom:=TRUE]), 
               color='grey90', size = -0.15), dpi = 600) + 
    geom_point(size=-0.2) + 
    scale_color_manual(values=c(opts$celltype.colors, opts$celltype_extended.colors)) + 
    coord_fixed(ratio = 0.75) + 
    facet_wrap(~label, ncol = 1) + 
    theme_void() + 
    theme(legend.position='right',
          strip.background=element_blank(),
          strip.text=element_text(size=8))

# %%
ggsave(file.path(io$basedir, 'figures/umap_projection.pdf'), 
       plot = p + theme(legend.position = 'none'), 
       width = 40, height = 90, units = "mm")

# %%
# options(repr.plot.width=25, repr.plot.height=3)
colors = c(opts$celltype.colors, opts$celltype_extended.colors)
names(colors) = gsub('_', ' ', names(colors))
celltype_legend = as_ggplot(get_legend(ggplot(meta, aes(umapX, umapY, color=gsub('_', ' ', celltype_updated))) +
                geom_point(size=1) + 
                scale_color_manual(values=colors) + 
                guides(color=guide_legend(nrow=7, byrow=FALSE)) +
                theme_void() + 
                theme(#legend.spacing.x = unit(0, 'mm'),
                     # legend.spacing.y = unit(2, 'in'),
                      legend.key.size = unit(2, "mm"),
                      legend.text = element_text(size=6),
                      legend.title = element_blank())))

# pdf(file = file.path(io$basedir, 'figures/umap_projection_legend.pdf'),   # The directory you want to save the file in
#     width = 15, # The width of the plot in inches
#     height = 2) # The height of the plot in inches
# celltype_legend
# dev.off()

celltype_legend
ggsave(file.path(io$basedir, 'figures/umap_projection_legend.pdf'), width = 180, height = 20, units = "mm")
# Out:
# plot without title

# %% [markdown]
# ### Celltype proportions

# %%
celltype2germlayer = c(
    'Amniotic_ectoderm' = 'ectoderm', 
    'Surface_ectoderm' = 'ectoderm', 
    'Caudal_neurectoderm' = 'ectoderm',
    'Rostral_neurectoderm' = 'ectoderm', 
    'Spinal_cord' = 'ectoderm', 
    'NMP' = 'ectoderm', 
    'Forebrain_Midbrain_Hindbrain' = 'ectoderm', 
    'Neural_crest' = 'ectoderm', 

    'Notochord' = 'endoderm', 
    'Def._endoderm' = 'endoderm', 
    'Gut' = 'endoderm', 

    'PGC' = 'other', 
    'Caudal_epiblast' = 'other', 
    'Mixed' = 'other', 

    'Intermediate_mesoderm' = 'mesoderm', 
    'Nascent_mesoderm' = 'mesoderm', 
    'Lateral_plate_mesoderm' = 'mesoderm', 
    'Allantois' = 'mesoderm', 
    'Somitic_mesoderm' = 'mesoderm', 
    'Caudal_Mesoderm' = 'mesoderm', 
    'Mesenchyme' = 'mesoderm', 
    'Pharyngeal_mesoderm' = 'mesoderm', 
    'Paraxial_mesoderm' = 'mesoderm', 
    'Cardiomyocytes' = 'mesoderm', 
    'Venous_endothelium' = 'mesoderm', 
    'Embryo_proper_endothelium' = 'mesoderm', 
    'Allantois_endothelium' = 'mesoderm', 
    'YS_endothelium' = 'mesoderm', 
    'Blood_progenitors_1' = 'mesoderm', 
    'Blood_progenitors_2' = 'mesoderm',
    'Erythroid' = 'mesoderm'
)

# %%
meta = fread('/rds/project/rds-SDzz0CATGms/users/bt392/01_Eomes_RNA/results/rna/mapping/manual/metadata_mapping_updated.txt.gz')%>%
    .[!celltype_updated%in%c("Visceral_endoderm","ExE_endoderm","ExE_ectoderm","Parietal_endoderm")] %>%
    .[,pool:=stringr::str_replace_all(sample,opts$sample2pool)]

# %%
table(meta$tdTom)
# Out:
# FALSE  TRUE
# 19284  8561

# %%
table(meta$tdTom, meta$celltype_updated)
# Out:
#
#         Allantois Allantois_endothelium Amniotic_ectoderm
#   FALSE       650                   247               108
#   TRUE       1143                   179               360
#
#         Anterior_Primitive_Streak Blood_progenitors_1 Blood_progenitors_2
#   FALSE                         1                  61                 408
#   TRUE                          0                   0                   0
#
#         Cardiomyocytes Caudal_epiblast Caudal_Mesoderm Caudal_neurectoderm
#   FALSE            423             443             196                 117
#   TRUE               2             448             449                  99
#
#         Def._endoderm Embryo_proper_endothelium  EMP Endocardium Epiblast
#   FALSE            64                       177   16           9        0
#   TRUE              0                        22    0           0        2
#
#         Erythroid Forebrain_Midbrain_Hindbrain  Gut
#   FALSE      4069                         2060  793
#   TRUE          1                          311   10
#
#         Haematoendothelial_progenitors Intermediate_mesoderm
#   FALSE                             11                   945
#   TRUE                               0                  1444
#
#         Lateral_plate_mesoderm Mesenchyme Nascent_mesoderm Neural_crest  NMP
#   FALSE                    788        800                7          347  629
#   TRUE                    1919         55                4           12  342
#
#         Non-neural_ectoderm Notochord Paraxial_mesoderm  PGC
#   FALSE                   1        58              1074   23
#   TRUE                    0         1                11  201
#
#         Pharyngeal_mesoderm Primitive_Streak Rostral_neurectoderm
#   FALSE                1010                0                  704
#   TRUE                   53                1                  350
#
#         Somitic_mesoderm Spinal_cord Surface_ectoderm Venous_endothelium
#   FALSE              536         772             1434                165
#   TRUE               317         228              588                  9
#
#         YS_endothelium YS_mesothelium
#   FALSE             51             87
#   TRUE               0              0

# %%
tmp = meta %>% copy() %>% 
    .[,tot := .N, by = 'sample'] %>% 
    .[,prop := .N/tot, by = c('sample', 'celltype_updated')] %>% 
    unique(by = c('sample', 'celltype_updated'))

all = merge(as.data.table(expand.grid(unique(tmp$sample), unique(tmp$celltype_updated))) %>% 
                        setnames(c('sample', 'celltype_updated')),
          tmp %>% copy() %>% .[,c('sample', 'tdTom', 'pool')] %>% unique(by='sample'), by = 'sample'
           )

tmp = merge(tmp, all, by=c('sample', 'celltype_updated', 'tdTom', 'pool'), all = TRUE) %>% 
        replace(., is.na(.), 0)

# %%
head(tmp2)
# Out:
#   pool  celltype_updated             KO           WT          log2fc
# 1 pool1 Forebrain_Midbrain_Hindbrain 0.0234782609 0.113569937 -2.26932154
# 2 pool1 Erythroid                    0.0008695652 0.283924843 -8.19446347
# 3 pool1 Cardiomyocytes               0.0000000000 0.021294363 -7.74108693
# 4 pool1 Lateral_plate_mesoderm       0.2026086957 0.021711900  3.21622064
# 5 pool1 Neural_crest                 0.0008695652 0.007515658 -2.97355877
# 6 pool1 NMP                          0.0426086957 0.040083507  0.08792635

# %%
# Calculate differential abundance statistics
tmp = meta %>% copy() %>% 
    .[,tot := .N, by = 'sample'] %>% 
    .[,prop := .N/tot, by = c('sample', 'celltype_updated')] %>% 
    unique(by = c('sample', 'celltype_updated'))

all = merge(as.data.table(expand.grid(unique(tmp$sample), unique(tmp$celltype_updated))) %>% 
                        setnames(c('sample', 'celltype_updated')),
          tmp %>% copy() %>% .[,c('sample', 'tdTom', 'pool')] %>% unique(by='sample'), by = 'sample'
           )

tmp = merge(tmp, all, by=c('sample', 'celltype_updated', 'tdTom', 'pool'), all = TRUE) %>% 
         replace(., is.na(.), 0)
        #replace(., is.na(.), 1e-3)

tmp2 = merge(tmp %>% copy() %>%
                .[tdTom == TRUE] %>% 
                .[,c('pool', 'celltype_updated', 'prop')] %>% setnames('prop', 'KO'),
             tmp %>% copy() %>%
                .[tdTom == FALSE] %>% 
                .[,c('pool', 'celltype_updated', 'prop')] %>% setnames('prop', 'WT'),
             by = c('pool', 'celltype_updated'), keep.all=TRUE
             ) %>% 
     .[,log2fc := log2((KO+1e-5)/(WT+1e-5))] %>% 
    #.[,fc := (KO)/(WT)] %>% 
    .[KO>0 | WT > 0] # remove pools where both are 0

stats = lapply(unique(tmp2$celltype_updated), function(x){
    tmp3 = tmp2 %>% copy() %>% 
            .[celltype_updated == x]
    if(nrow(tmp3) > 1){
        tmp4 = data.table(celltype_updated = x,
                          avg_log2fc = mean(tmp3$log2fc),
                          sd_log2fc = sd(tmp3$log2fc),
                          #p_value = t.test(tmp3$KO, tmp3$WT, paired=TRUE, alternative = "two.sided")$p.value,
                          p_value = t.test(tmp3$log2fc)$p.value,
                          #p_value = t.test(tmp3$fc, mu=1)$p.value,
                          samples = nrow(tmp3))
    } else{
        tmp4 = data.table(celltype_updated = x,
                  avg_log2fc = mean(tmp3$log2fc),
                  sd_log2fc = NA,
                  p_value = NA,
                  samples = 1)
    }
    return(tmp4)
}) %>% rbindlist() %>% 
    .[,FDR := p.adjust(p_value, n=nrow(.), method='fdr')] %>% 
    .[,germ_layer := celltype2germlayer[as.character(celltype_updated)]] %>% 
    .[,sig := ifelse(FDR <= 0.05, TRUE, FALSE)]

# %%
options(repr.plot.width=15)
ggplot(stats[order(avg_log2fc)][,celltype_updated := factor(celltype_updated, levels = unique(celltype_updated))], 
           aes(celltype_updated, avg_log2fc, fill = celltype_updated, color=sig)) + 
    geom_bar(stat='identity', linewidth=0.7) + 
    geom_errorbar(aes(ymin=avg_log2fc-sd_log2fc, ymax=avg_log2fc+sd_log2fc), width=.2, color='black') + 
    scale_fill_manual(values=c(opts$celltype.colors, opts$celltype_extended.colors)) + 
    scale_color_manual(values=c('TRUE' = 'red', 'FALSE' = 'black')) + 
    facet_grid(cols = vars(germ_layer), scales='free', space='free') + 
    geom_hline(yintercept=0) + 
    theme_bw() + 
        theme(legend.position = 'none', 
            axis.text = element_text(size=15, color='black'),
                          axis.text.x = element_text(size=15, color='black', angle=-90, hjust=0, vjust=0.5),

              axis.title = element_text(size=20, color='black'),
              axis.title.x = element_blank(), 
              legend.text = element_text(size=15),
              legend.title = element_text(size=20),
              plot.title = element_text(size=25),
              panel.border = element_rect(color='black', linewidth=1.3),
                       strip.background=element_blank(),
          strip.text.x = element_blank())
# Out:
# plot without title

# %%
ct = 'Venous_endothelium'
tmp2[celltype_updated == ct]
stats[celltype_updated == ct]

t.test(tmp2[celltype_updated == ct]$log2fc, mu=0)
t.test(tmp2[celltype_updated == ct]$fc, mu=1)
# Out:
#   pool  celltype_updated   KO          WT          log2fc
# 1 pool1 Venous_endothelium 0.000000000 0.010855950 -10.085599
# 2 pool2 Venous_endothelium 0.001443001 0.007144648  -2.299845
# 3 pool3 Venous_endothelium 0.001195815 0.003193188  -1.409500
# 4 pool4 Venous_endothelium 0.000000000 0.013584320 -10.408788
#   celltype_updated   avg_log2fc sd_log2fc p_value   samples FDR
# 1 Venous_endothelium -6.050933  4.86083   0.0885098 4       0.1245693
#   germ_layer sig
# 1 mesoderm   FALSE
# 	One Sample t-test
#
# data:  tmp2[celltype_updated == ct]$log2fc
# t = -2.4897, df = 3, p-value = 0.08851
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  -13.785597   1.683732
# sample estimates:
# mean of x
# -6.050933
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Error in var(x): 'x' is NULL
# Traceback:
#
# 1. t.test(tmp2[celltype_updated == ct]$fc, mu = 1)
# 2. t.test.default(tmp2[celltype_updated == ct]$fc, mu = 1)
# 3. var(x)

# %%
t.test(tmp2[celltype_updated == ct]$log2fc, mu=0)
t.test(tmp2[celltype_updated == ct]$fc, mu=1)
# Out:
# 	One Sample t-test
#
# data:  tmp2[celltype_updated == ct]$log2fc
# t = -2.4897, df = 3, p-value = 0.08851
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  -13.785597   1.683732
# sample estimates:
# mean of x
# -6.050933
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Error in var(x): 'x' is NULL
# Traceback:
#
# 1. t.test(tmp2[celltype_updated == ct]$fc, mu = 1)
# 2. t.test.default(tmp2[celltype_updated == ct]$fc, mu = 1)
# 3. var(x)

# %%
# using edgeR
library(edgeR)

matrix_edgeR = meta %>% copy() %>% 
    .[,tot := .N, by = 'sample'] %>% 
    .[,N := .N, by = c('sample', 'celltype_updated')] %>% 
    unique(by = c('sample', 'celltype_updated')) %>% 
    .[,c('sample', 'celltype_updated', 'N')] %>% 
    dcast(sample ~ celltype_updated, value.var = 'N') %>% 
    replace(., is.na(.), 0) %>%
    as.data.frame(.) %>% tibble::column_to_rownames('sample')

meta_edgeR = meta %>% copy() %>% 
    unique(by='sample') %>% 
     .[,c('sample', 'tdTom', 'pool')] %>%
    as.data.frame(.) %>% tibble::column_to_rownames('sample')
# Out:
# Loading required package: limma
#
#
# Attaching package: ‘limma’
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     plotMA
#
#
#
# Attaching package: ‘edgeR’
#
#
# The following object is masked from ‘package:SingleCellExperiment’:
#
#     cpm

# %%
#extra.info <- colData(merged)[match(colnames(abundances), merged$sample),]
y.ab <- DGEList(t(matrix_edgeR), samples=meta_edgeR)

# %%
keep <- filterByExpr(y.ab, min.count = 0, min.total.count = 0)
y.ab <- y.ab[keep,]
summary(keep)
# Out:
# Warning message in filterByExpr.DGEList(y.ab, min.count = 0, min.total.count = 0):
# “All samples appear to belong to the same group.”
#    Mode    TRUE
# logical      38

# %%
keep[keep==FALSE]
# Out:
# named logical(0)

# %%
y.ab$samples
# Out:
#                             group lib.size norm.factors tdTom pool
# SLX-20795_SITTA11_HKTG2DRXY 1      601     1            FALSE pool2
# SLX-20795_SITTA12_HKTG2DRXY 1     2395     1            FALSE pool3
# SLX-20795_SITTB11_HKTG2DRXY 1     5153     1            FALSE pool4
# SLX-20795_SITTF11_HKTG2DRXY 1     3345     1             TRUE pool3
# SLX-20795_SITTG10_HKTG2DRXY 1     3465     1             TRUE pool2
# SLX-20795_SITTG11_HKTG2DRXY 1     3758     1             TRUE pool1
# SLX-20795_SITTH10_HKTG2DRXY 1     7978     1            FALSE pool1
# SLX-20795_SITTH11_HKTG2DRXY 1     1150     1             TRUE pool4

# %%
design <- model.matrix(~factor(pool) + tdTom, y.ab$samples)

# %%
y.ab <- estimateDisp(y.ab, design)
summary(y.ab$common.dispersion)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.8087  0.8087  0.8087  0.8087  0.8087  0.8087

# %%
plotBCV(y.ab, cex=1)
# Out:
# plot without title

# %%
fit.ab <- glmQLFit(y.ab, design, robust=TRUE, abundance.trend=FALSE)
summary(fit.ab$var.prior)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.402   1.402   1.402   1.402   1.402   1.402

# %%
plotQLDisp(fit.ab, cex=1)
# Out:
# plot without title

# %%
res <- glmQLFTest(fit.ab, coef=ncol(design))
summary(decideTests(res))
# Out:
#        tdTomTRUE
# Down           0
# NotSig        38
# Up             0

# %%
res
# Out:
# An object of class "DGELRT"
# $coefficients
#                           (Intercept) factor(pool)pool2 factor(pool)pool3
# Allantois                   -3.729149        1.41634299         0.9171019
# Allantois_endothelium       -4.686265       -0.01770636         0.5597637
# Amniotic_ectoderm           -5.636630        3.07718995         0.8101667
# Anterior_Primitive_Streak   -8.878936       -0.71918028        -0.9515193
# Blood_progenitors_1         -4.983783       -3.67950439        -1.2705024
#                           factor(pool)pool4  tdTomTRUE
# Allantois                        0.79184683  0.5036909
# Allantois_endothelium            0.06598326  0.3686875
# Amniotic_ectoderm                1.52465516  0.3085464
# Anterior_Primitive_Streak       -1.22837260 -0.8170647
# Blood_progenitors_1             -0.79835071 -2.5504481
# 33 more rows ...
#
# $fitted.values
#                           SLX-20795_SITTA11_HKTG2DRXY
# Allantois                                5.947138e+01
# Allantois_endothelium                    5.422337e+00
# Amniotic_ectoderm                        4.646422e+01
# Anterior_Primitive_Streak                3.468242e-08
# Blood_progenitors_1                      1.686303e-07
#                           SLX-20795_SITTA12_HKTG2DRXY
# Allantois                                1.438139e+02
# Allantois_endothelium                    3.855699e+01
# Amniotic_ectoderm                        1.911576e+01
# Anterior_Primitive_Streak                4.936155e-08
# Blood_progenitors_1                      4.465437e+00
#                           SLX-20795_SITTB11_HKTG2DRXY
# Allantois                                2.729926e+02
# Allantois_endothelium                    5.059603e+01
# Amniotic_ectoderm                        8.419636e+01
# Anterior_Primitive_Streak                4.183501e-08
# Blood_progenitors_1                      1.589390e+01
#                           SLX-20795_SITTF11_HKTG2DRXY
# Allantois                                3.324525e+02
# Allantois_endothelium                    7.795168e+01
# Amniotic_ectoderm                        3.636649e+01
# Anterior_Primitive_Streak                9.167974e-15
# Blood_progenitors_1                      3.669575e-01
#                           SLX-20795_SITTG10_HKTG2DRXY
# Allantois                                5.675118e+02
# Allantois_endothelium                    4.525296e+01
# Amniotic_ectoderm                        3.648940e+02
# Anterior_Primitive_Streak                2.659084e-14
# Blood_progenitors_1                      5.720387e-08
#                           SLX-20795_SITTG11_HKTG2DRXY
# Allantois                                1.491879e+02
# Allantois_endothelium                    4.998030e+01
# Amniotic_ectoderm                        1.808829e+01
# Anterior_Primitive_Streak                6.264072e-08
# Blood_progenitors_1                      1.747017e+00
#                           SLX-20795_SITTH10_HKTG2DRXY
# Allantois                                   191.35195
# Allantois_endothelium                        73.30007
# Amniotic_ectoderm                            28.19133
# Anterior_Primitive_Streak                     1.00000
# Blood_progenitors_1                          63.03378
#                           SLX-20795_SITTH11_HKTG2DRXY
# Allantois                                1.008386e+02
# Allantois_endothelium                    1.634503e+01
# Amniotic_ectoderm                        2.559472e+01
# Anterior_Primitive_Streak                1.241571e-15
# Blood_progenitors_1                      2.087033e-01
# 33 more rows ...
#
# $deviance
# [1] 2.412611e+00 6.621310e+00 2.730542e+00 2.389098e-07 1.632089e+00
# 33 more elements ...
#
# $iter
# [1]  7 12  9 16 17
# 33 more elements ...
#
# $failed
# [1] FALSE FALSE FALSE FALSE FALSE
# 33 more elements ...
#
# $method
# [1] "levenberg"
#
# $unshrunk.coefficients
#                           (Intercept) factor(pool)pool2 factor(pool)pool3
# Allantois                   -3.730329        1.41722892         0.9177104
# Allantois_endothelium       -4.689881       -0.01818654         0.5608805
# Amniotic_ectoderm           -5.645428        3.08551622         0.8148031
# Anterior_Primitive_Streak   -8.984443      -14.59118484       -15.6207896
# Blood_progenitors_1         -4.840772      -17.15338004        -1.4439991
#                           factor(pool)pool4   tdTomTRUE
# Allantois                         0.7924389   0.5038934
# Allantois_endothelium             0.0664202   0.3698682
# Amniotic_ectoderm                 1.5312458   0.3090513
# Anterior_Primitive_Streak       -16.5524236 -15.8330495
# Blood_progenitors_1              -0.9406268  -2.8329599
# 33 more rows ...
#
# $df.residual
# [1] 3 3 3 3 3
# 33 more elements ...
#
# $design
#                             (Intercept) factor(pool)pool2 factor(pool)pool3
# SLX-20795_SITTA11_HKTG2DRXY           1                 1                 0
# SLX-20795_SITTA12_HKTG2DRXY           1                 0                 1
# SLX-20795_SITTB11_HKTG2DRXY           1                 0                 0
# SLX-20795_SITTF11_HKTG2DRXY           1                 0                 1
# SLX-20795_SITTG10_HKTG2DRXY           1                 1                 0
# SLX-20795_SITTG11_HKTG2DRXY           1                 0                 0
# SLX-20795_SITTH10_HKTG2DRXY           1                 0                 0
# SLX-20795_SITTH11_HKTG2DRXY           1                 0                 0
#                             factor(pool)pool4 tdTomTRUE
# SLX-20795_SITTA11_HKTG2DRXY                 0         0
# SLX-20795_SITTA12_HKTG2DRXY                 0         0
# SLX-20795_SITTB11_HKTG2DRXY                 1         0
# SLX-20795_SITTF11_HKTG2DRXY                 0         1
# SLX-20795_SITTG10_HKTG2DRXY                 0         1
# SLX-20795_SITTG11_HKTG2DRXY                 0         1
# SLX-20795_SITTH10_HKTG2DRXY                 0         0
# SLX-20795_SITTH11_HKTG2DRXY                 1         1
# attr(,"assign")
# [1] 0 1 1 1 2
# attr(,"contrasts")
# attr(,"contrasts")$`factor(pool)`
# [1] "contr.treatment"
#
# attr(,"contrasts")$tdTom
# [1] "contr.treatment"
#
#
# $offset
#          [,1]     [,2]     [,3]     [,4]     [,5]     [,6]     [,7]     [,8]
# [1,] 6.398595 7.781139 8.547334 8.115222 8.150468 8.231642 8.984443 7.047517
# attr(,"class")
# [1] "CompressedMatrix"
# attr(,"Dims")
# [1] 5 8
# attr(,"repeat.row")
# [1] TRUE
# attr(,"repeat.col")
# [1] FALSE
# 33 more rows ...
#
# $dispersion
# [1] 0.7101529 0.7925134 0.7311051 1.1861550 1.0856338
# 33 more elements ...
#
# $prior.count
# [1] 0.125
#
# $df.residual.zeros
# [1] 3 3 3 0 2
# 33 more elements ...
#
# $df.prior
# [1] 147.8061 147.8061 147.8061 147.8061 147.8061
# 33 more elements ...
#
# $var.post
# [1] 1.390258 1.418166 1.392366 1.402153 1.394328
# 33 more elements ...
#
# $var.prior
# [1] 1.402153
#
# $samples
#                             group lib.size norm.factors tdTom  pool
# SLX-20795_SITTA11_HKTG2DRXY     1      601            1 FALSE pool2
# SLX-20795_SITTA12_HKTG2DRXY     1     2395            1 FALSE pool3
# SLX-20795_SITTB11_HKTG2DRXY     1     5153            1 FALSE pool4
# SLX-20795_SITTF11_HKTG2DRXY     1     3345            1  TRUE pool3
# SLX-20795_SITTG10_HKTG2DRXY     1     3465            1  TRUE pool2
# SLX-20795_SITTG11_HKTG2DRXY     1     3758            1  TRUE pool1
# SLX-20795_SITTH10_HKTG2DRXY     1     7978            1 FALSE pool1
# SLX-20795_SITTH11_HKTG2DRXY     1     1150            1  TRUE pool4
#
# $AveLogCPM
# [1] 16.272946 13.780137 14.872135  9.219105 11.049745
# 33 more elements ...
#
# $table
#                                logFC    logCPM         F     PValue
# Allantois                  0.7266723 16.272946 0.4181856 0.51914366
# Allantois_endothelium      0.5319036 13.780137 0.1630446 0.68712524
# Amniotic_ectoderm          0.4451384 14.872135 0.1417749 0.70722277
# Anterior_Primitive_Streak -1.1787752  9.219105 0.4325333 0.51207431
# Blood_progenitors_1       -3.6795188 11.049745 4.0749631 0.04587026
# 33 more rows ...
#
# $comparison
# [1] "tdTomTRUE"
#
# $df.test
# [1] 1 1 1 1 1
# 33 more elements ...
#
# $df.total
# [1] 114 114 114 114 114
# 33 more elements ...

# %%
ggplot(as.data.table(res$table, keep.rownames=T), aes(rn, logFC, fill = rn, color = PValue<0.05)) + geom_bar(stat = 'identity')  +
    scale_fill_manual(values=c(opts$celltype.colors, opts$celltype_extended.colors)) + 
    scale_color_manual(values=c('TRUE' = 'red', 'FALSE' = 'black')) + 
    geom_hline(yintercept=0) + 
    theme_bw() + 
        theme(legend.position = 'none', 
            axis.text = element_text(size=15, color='black'),
                          axis.text.x = element_text(size=15, color='black', angle=-90, hjust=0, vjust=0.5),

              axis.title = element_text(size=20, color='black'),
              axis.title.x = element_blank(), 
              legend.text = element_text(size=15),
              legend.title = element_text(size=20),
              plot.title = element_text(size=25),
              panel.border = element_rect(color='black', linewidth=1.3),
                       strip.background=element_blank(),
          strip.text.x = element_blank())
# Out:
# plot without title

# %%
res$table
# Out:
#                                logFC       logCPM    F           PValue
# Allantois                       0.72667230 16.272946 0.418185589 0.519143657
# Allantois_endothelium           0.53190360 13.780137 0.163044551 0.687125236
# Amniotic_ectoderm               0.44513840 14.872135 0.141774875 0.707222774
# Anterior_Primitive_Streak      -1.17877516  9.219105 0.432533267 0.512074305
# Blood_progenitors_1            -3.67951876 11.049745 4.074963066 0.045870262
# Blood_progenitors_2            -5.01053398 13.526694 7.433322910 0.007414613
# Cardiomyocytes                 -3.17091489 13.501705 3.599684049 0.060320475
# Caudal_Mesoderm                 1.21939098 14.951658 1.042385181 0.309429154
# Caudal_epiblast                -0.18522669 15.341738 0.028646398 0.865898023
# Caudal_neurectoderm            -0.60389242 13.405727 0.269426172 0.604723181
# Def._endoderm                  -2.58530740 11.278494 1.691962978 0.195965608
# EMP                            -4.11323373  9.940939 3.683688499 0.057446906
# Embryo_proper_endothelium      -1.05827373 12.524406 0.564478749 0.454009497
# Endocardium                    -2.03988853  9.754935 1.047110472 0.308340050
# Epiblast                        2.60566354  9.420143 1.807113289 0.181523872
# Erythroid                      -6.38457929 16.844626 6.487148947 0.014857727
# Forebrain_Midbrain_Hindbrain   -0.76358563 16.166693 0.497427909 0.482071066
# Gut                            -2.52573518 14.420118 2.823890333 0.095609258
# Haematoendothelial_progenitors -4.27050159  9.875397 3.811582254 0.053351166
# Intermediate_mesoderm           0.91095673 16.692221 0.688044398 0.408563883
# Lateral_plate_mesoderm          1.72946763 16.840399 2.216901183 0.139268061
# Mesenchyme                     -1.42655641 14.445543 1.493537001 0.224189382
# NMP                             0.50381369 15.222675 0.230319442 0.632206589
# Nascent_mesoderm                0.90105383  9.892302 0.157845342 0.691890936
# Neural_crest                   -1.38567850 13.174623 1.047077148 0.308347714
# Non-neural_ectoderm            -1.17877516  9.219105 0.432533267 0.512074305
# Notochord                      -1.58355780 11.305011 0.651937718 0.421102237
# PGC                             2.85729795 13.755238 4.492653528 0.036210472
# Paraxial_mesoderm              -2.94750553 14.855641 3.766663006 0.054752743
# Pharyngeal_mesoderm            -1.89156823 14.834906 2.367778176 0.126634331
# Primitive_Streak                0.67858845  9.261895 0.199193303 0.656219382
# Rostral_neurectoderm           -1.07207906 15.214694 0.980212013 0.324243226
# Somitic_mesoderm                0.22067636 15.115094 0.040437399 0.840986140
# Spinal_cord                    -0.52216035 15.109981 0.253690832 0.615460083
# Surface_ectoderm               -0.08927027 16.178669 0.007514949 0.931070954
# Venous_endothelium             -2.12080207 12.415563 1.998203606 0.160210636
# YS_endothelium                 -3.22538698 10.964523 3.052833740 0.083289314
# YS_mesothelium                 -3.98401644 11.460423 4.832731832 0.029944762
